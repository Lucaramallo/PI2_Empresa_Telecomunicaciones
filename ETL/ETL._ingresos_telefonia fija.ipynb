# %%
import pandas as pd

# %%
df = pd.read_csv('../CSV data importada/CSV Telefonia Fija/Ingresos trimestrales por la prestación del servicio de telefonía fija.csv',encoding='utf-8', thousands='.', decimal=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Año                    35 non-null     int64
#  1   Trimestre              35 non-null     int64
#  2   Ingresos (miles de $)  35 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 968.0 bytes

# %%
df.isnull().sum()
# Out:
# Año                      0
# Trimestre                0
# Ingresos (miles de $)    0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      Año  Trimestre  Ingresos (miles de $)
# 0   2014          1             2916071.75
# 1   2014          2             2974865.20
# 2   2014          3             3105462.02
# 3   2014          4             3339690.90
# 4   2015          1             3260124.75
# 5   2015          2             3425518.48
# 6   2015          3             3590883.18
# 7   2015          4             3815364.12
# 8   2016          1             4198260.39
# 9   2016          2             4718769.82
# 10  2016          3             4951967.66
# 11  2016          4             4964596.39
# 12  2017          1             6375681.76
# 13  2017          2             6970617.22
# 14  2017          3             6667943.53
# 15  2017          4             5514336.19
# 16  2018          1             8252279.99
# 17  2018          2             7911723.07
# 18  2018          3            10111350.57
# 19  2018          4             8997157.88
# 20  2019          1            12238568.39
# ...

# %%
df.to_csv('../ETL/CSV Cleaned/Ingresos_telefonia_fija_powerbi.csv', mode='w', index=True,header=True)
